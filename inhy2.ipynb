# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/ENVIRONMENTAL_data_BV_FS2.csv')
df.head()
# Out:
#   container   crop  rep  bay placement      date      time   temp_c  \
# 0       FS2  basil  1.0  207    bottom  20180911  14:10:00  24.6006
# 1       FS2  basil  1.0  207    bottom  20180911  14:20:00  25.0082
# 2       FS2  basil  1.0  207    bottom  20180911  14:30:00  25.2441
# 3       FS2  basil  1.0  207    bottom  20180911  14:40:00  25.5444
# 4       FS2  basil  1.0  207    bottom  20180911  14:50:00  25.5551
#
#    relative_humidity_%  dewpoint
# 0              58.9300   16.0403
# 1              55.5349   15.4930
# 2              61.0204   17.1932
# 3              60.0820   17.2304
# 4              55.2679   15.9263

# %%
ax =df.plot(y='temp_c', figsize=(20,10), title="Temperature")
fig = ax.get_figure()
fig.savefig('air_temp_plot.png')

# %%
ax =df.plot(y='relative_humidity_%', figsize=(20,10), title="Humidity")
fig = ax.get_figure()
fig.savefig('air_rh_plot.png')
