# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/env4_rep1.csv')
data.head()
# Out:
#    bay  humidity  water temp    ec    ph   temp     N     P     K    Ca    Mg  \
# 0  201     56.75       23.84  2.77  6.03  22.41  5.04  1.03  6.59  1.74  0.85
# 1  202     58.02       24.06  2.82  6.27  22.54  5.55  1.22  5.72  2.39  1.04
# 2  203     61.08       24.00  2.65  6.25  22.41  6.16  1.04  6.48  2.46  0.86
# 3  204     58.94       24.89  2.56  6.46  22.93  5.70  0.31  5.84  0.98  0.39
# 4  205     60.10       24.36  2.44  6.20  22.55  5.26  1.01  5.76  2.78  0.73
#
#       S     Fe      Mn      B     Cu      Zn    Mo      Na    Al
# 0  3731  75.43  315.27  58.38  35.69  288.76  1.64  166.47  1.92
# 1  3295  58.34  340.85  62.32  26.25  213.76  2.20   80.57  2.27
# 2  3582  64.83  392.44  53.54  37.34  353.12  1.54  271.96  2.84
# 3  2326  51.75   25.26  39.31   4.45   30.81  0.00    0.00  9.49
# 4  3832  68.03  306.97  51.49  30.52  240.84  1.59  152.33  0.66

# %%
x1=data["humidity"]
x2=data["water temp"]
x3=data["ph"]
x4=data["ec"]
x5=data["temp"]


var=data["N"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]

print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
# Out:
# humidity 61.08
# water temp 24.0
# ph 6.25
# ec 2.65
# temperature 22.41

# %%
df=pd.read_csv('/content/env3_rep1.csv')
df.head()
# Out:
#    bay  humidity  water temp    ec    ph   temp  PAR_DLI  PAR_Illuminance  \
# 0  201     56.75       23.84  2.77  6.03  22.41    31.05          6328.44
# 1  202     58.02       24.06  2.82  6.27  22.54    26.89          5343.22
# 2  203     61.08       24.00  2.65  6.25  22.41    32.52          6488.11
# 3  204     58.94       24.89  2.56  6.46  22.93    31.43          6424.83
# 4  205     60.10       24.36  2.44  6.20  22.55    36.51          7382.94
#
#    PAR_PPFD (400 - 700 nm)  PAR_PPFD B (400 - 499 nm)  ...    Mg     S     Fe  \
# 0                   359.45                     100.73  ...  0.85  3731  75.43
# 1                   311.32                      85.38  ...  1.04  3295  58.34
# 2                   376.46                     103.36  ...  0.86  3582  64.83
# 3                   363.85                     102.34  ...  0.39  2326  51.75
# 4                   422.66                     119.22  ...  0.73  3832  68.03
#
#        Mn      B     Cu      Zn    Mo      Na    Al
# ...

# %%
x1=df["humidity"]
x2=df["water temp"]
x3=df["ph"]
x4=df["ec"]
x5=df["temp"]
x6=df["PAR_DLI"]
x7=df["PAR_Illuminance"]
x8=df["PAR_PPFD (400 - 700 nm)"]
x9=df["PAR_PPFD B (400 - 499 nm)"]
x10=df["PAR_PPFD FR (701 - 780 nm)"]
x11=df["PAR_PPFD G (500 - 599 nm)"]
x12=df["PAR_PPFD R (600 - 700 nm)"]
x13=df["PAR_PPFD UV (380 - 399 nm)"]
x14=df["PAR_R/B"]
x15=df["PAR_R/FR"]
x16=df["PAR_YPFD (380 - 780 nm)"]
x17=df["PAR_YPFD (400 - 700 nm)"]
x18=df["PAR_YPFD B (400 - 499 nm)"]
x19=df["PAR_YPFD FR (701 - 780 nm)"]
x20=df["PAR_YPFD G (500 - 599 nm)"]
x21=df["PAR_YPFD R (600 - 700 nm)"]
x22=df["PAR_YPFD UV (380 - 399 nm)"]


var=df["N"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]
max_x6=x6[max_index]
max_x7=x7[max_index]
max_x8=x8[max_index]
max_x9=x9[max_index]
max_x10=x10[max_index]
max_x11=x11[max_index]
max_x12=x12[max_index]
max_x13=x13[max_index]
max_x14=x14[max_index]
max_x15=x15[max_index]
max_x16=x16[max_index]
max_x17=x17[max_index]
max_x18=x18[max_index]
max_x19=x19[max_index]
max_x20=x20[max_index]
max_x21=x21[max_index]
max_x22=x22[max_index]

print("Nitrogen\n\n")
print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
print("PAR_DLI",max_x6)
print("PAR_Illuminance",max_x7)
print("PAR_PPFD (400 - 700 nm)",max_x8)
print("PAR_PPFD B (400 - 499 nm)",max_x9)
print("PAR_PPFD FR (701 - 780 nm)",max_x10)
print("PAR_PPFD G (500 - 599 nm)",max_x11)
print("PAR_PPFD R (600 - 700 nm)",max_x12)
print("PAR_PPFD UV (380 - 399 nm)",max_x13)
print("PAR_R/B",max_x14)
print("PAR_R/FR",max_x15)
print("PAR_YPFD (380 - 780 nm)",max_x16)
print("PAR_YPFD (400 - 700 nm)",max_x17)
print("PAR_YPFD B (400 - 499 nm)",max_x18)
print("PAR_YPFD FR (701 - 780 nm)",max_x19)
print("PAR_YPFD G (500 - 599 nm)",max_x20)
print("PAR_YPFD R (600 - 700 nm)",max_x21)
print("PAR_YPFD UV (380 - 399 nm)",max_x22)
# Out:
# Nitrogen
#
#
# humidity 61.08
# water temp 24.0
# ph 6.25
# ec 2.65
# temperature 22.41
# PAR_DLI 32.52
# PAR_Illuminance 6488.11
# PAR_PPFD (400 - 700 nm) 376.46
# PAR_PPFD B (400 - 499 nm) 103.36
# PAR_PPFD FR (701 - 780 nm) 7.19
# PAR_PPFD G (500 - 599 nm) 21.38
# PAR_PPFD R (600 - 700 nm) 251.73
# PAR_PPFD UV (380 - 399 nm) 0.28
# PAR_R/B 2.44
# PAR_R/FR 35.22
# PAR_YPFD (380 - 780 nm) 328.14
# PAR_YPFD (400 - 700 nm) 326.38
# PAR_YPFD B (400 - 499 nm) 75.62
# PAR_YPFD FR (701 - 780 nm) 1.58
# PAR_YPFD G (500 - 599 nm) 18.89
# PAR_YPFD R (600 - 700 nm) 231.89
# PAR_YPFD UV (380 - 399 nm) 0.17

# %%
x1=df["humidity"]
x2=df["water temp"]
x3=df["ph"]
x4=df["ec"]
x5=df["temp"]
x6=df["PAR_DLI"]
x7=df["PAR_Illuminance"]
x8=df["PAR_PPFD (400 - 700 nm)"]
x9=df["PAR_PPFD B (400 - 499 nm)"]
x10=df["PAR_PPFD FR (701 - 780 nm)"]
x11=df["PAR_PPFD G (500 - 599 nm)"]
x12=df["PAR_PPFD R (600 - 700 nm)"]
x13=df["PAR_PPFD UV (380 - 399 nm)"]
x14=df["PAR_R/B"]
x15=df["PAR_R/FR"]
x16=df["PAR_YPFD (380 - 780 nm)"]
x17=df["PAR_YPFD (400 - 700 nm)"]
x18=df["PAR_YPFD B (400 - 499 nm)"]
x19=df["PAR_YPFD FR (701 - 780 nm)"]
x20=df["PAR_YPFD G (500 - 599 nm)"]
x21=df["PAR_YPFD R (600 - 700 nm)"]
x22=df["PAR_YPFD UV (380 - 399 nm)"]


var=df["P"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]
max_x6=x6[max_index]
max_x7=x7[max_index]
max_x8=x8[max_index]
max_x9=x9[max_index]
max_x10=x10[max_index]
max_x11=x11[max_index]
max_x12=x12[max_index]
max_x13=x13[max_index]
max_x14=x14[max_index]
max_x15=x15[max_index]
max_x16=x16[max_index]
max_x17=x17[max_index]
max_x18=x18[max_index]
max_x19=x19[max_index]
max_x20=x20[max_index]
max_x21=x21[max_index]
max_x22=x22[max_index]

print("Phosphorous\n\n")
print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
print("PAR_DLI",max_x6)
print("PAR_Illuminance",max_x7)
print("PAR_PPFD (400 - 700 nm)",max_x8)
print("PAR_PPFD B (400 - 499 nm)",max_x9)
print("PAR_PPFD FR (701 - 780 nm)",max_x10)
print("PAR_PPFD G (500 - 599 nm)",max_x11)
print("PAR_PPFD R (600 - 700 nm)",max_x12)
print("PAR_PPFD UV (380 - 399 nm)",max_x13)
print("PAR_R/B",max_x14)
print("PAR_R/FR",max_x15)
print("PAR_YPFD (380 - 780 nm)",max_x16)
print("PAR_YPFD (400 - 700 nm)",max_x17)
print("PAR_YPFD B (400 - 499 nm)",max_x18)
print("PAR_YPFD FR (701 - 780 nm)",max_x19)
print("PAR_YPFD G (500 - 599 nm)",max_x20)
print("PAR_YPFD R (600 - 700 nm)",max_x21)
print("PAR_YPFD UV (380 - 399 nm)",max_x22)
# Out:
# Phosphorous
#
#
# humidity 58.02
# water temp 24.06
# ph 6.27
# ec 2.82
# temperature 22.54
# PAR_DLI 26.89
# PAR_Illuminance 5343.22
# PAR_PPFD (400 - 700 nm) 311.32
# PAR_PPFD B (400 - 499 nm) 85.38
# PAR_PPFD FR (701 - 780 nm) 6.13
# PAR_PPFD G (500 - 599 nm) 17.89
# PAR_PPFD R (600 - 700 nm) 208.05
# PAR_PPFD UV (380 - 399 nm) 0.23
# PAR_R/B 2.43
# PAR_R/FR 33.9
# PAR_YPFD (380 - 780 nm) 271.28
# PAR_YPFD (400 - 700 nm) 269.81
# PAR_YPFD B (400 - 499 nm) 62.48
# PAR_YPFD FR (701 - 780 nm) 1.32
# PAR_YPFD G (500 - 599 nm) 15.8
# PAR_YPFD R (600 - 700 nm) 191.54
# PAR_YPFD UV (380 - 399 nm) 0.13

# %%
x1=df["humidity"]
x2=df["water temp"]
x3=df["ph"]
x4=df["ec"]
x5=df["temp"]
x6=df["PAR_DLI"]
x7=df["PAR_Illuminance"]
x8=df["PAR_PPFD (400 - 700 nm)"]
x9=df["PAR_PPFD B (400 - 499 nm)"]
x10=df["PAR_PPFD FR (701 - 780 nm)"]
x11=df["PAR_PPFD G (500 - 599 nm)"]
x12=df["PAR_PPFD R (600 - 700 nm)"]
x13=df["PAR_PPFD UV (380 - 399 nm)"]
x14=df["PAR_R/B"]
x15=df["PAR_R/FR"]
x16=df["PAR_YPFD (380 - 780 nm)"]
x17=df["PAR_YPFD (400 - 700 nm)"]
x18=df["PAR_YPFD B (400 - 499 nm)"]
x19=df["PAR_YPFD FR (701 - 780 nm)"]
x20=df["PAR_YPFD G (500 - 599 nm)"]
x21=df["PAR_YPFD R (600 - 700 nm)"]
x22=df["PAR_YPFD UV (380 - 399 nm)"]


var=df["K"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]
max_x6=x6[max_index]
max_x7=x7[max_index]
max_x8=x8[max_index]
max_x9=x9[max_index]
max_x10=x10[max_index]
max_x11=x11[max_index]
max_x12=x12[max_index]
max_x13=x13[max_index]
max_x14=x14[max_index]
max_x15=x15[max_index]
max_x16=x16[max_index]
max_x17=x17[max_index]
max_x18=x18[max_index]
max_x19=x19[max_index]
max_x20=x20[max_index]
max_x21=x21[max_index]
max_x22=x22[max_index]

print("Potassium\n\n")
print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
print("PAR_DLI",max_x6)
print("PAR_Illuminance",max_x7)
print("PAR_PPFD (400 - 700 nm)",max_x8)
print("PAR_PPFD B (400 - 499 nm)",max_x9)
print("PAR_PPFD FR (701 - 780 nm)",max_x10)
print("PAR_PPFD G (500 - 599 nm)",max_x11)
print("PAR_PPFD R (600 - 700 nm)",max_x12)
print("PAR_PPFD UV (380 - 399 nm)",max_x13)
print("PAR_R/B",max_x14)
print("PAR_R/FR",max_x15)
print("PAR_YPFD (380 - 780 nm)",max_x16)
print("PAR_YPFD (400 - 700 nm)",max_x17)
print("PAR_YPFD B (400 - 499 nm)",max_x18)
print("PAR_YPFD FR (701 - 780 nm)",max_x19)
print("PAR_YPFD G (500 - 599 nm)",max_x20)
print("PAR_YPFD R (600 - 700 nm)",max_x21)
print("PAR_YPFD UV (380 - 399 nm)",max_x22)
# Out:
# Potassium
#
#
# humidity 56.75
# water temp 23.84
# ph 6.03
# ec 2.77
# temperature 22.41
# PAR_DLI 31.05
# PAR_Illuminance 6328.44
# PAR_PPFD (400 - 700 nm) 359.45
# PAR_PPFD B (400 - 499 nm) 100.73
# PAR_PPFD FR (701 - 780 nm) 6.72
# PAR_PPFD G (500 - 599 nm) 20.58
# PAR_PPFD R (600 - 700 nm) 238.15
# PAR_PPFD UV (380 - 399 nm) 0.26
# PAR_R/B 2.37
# PAR_R/FR 35.43
# PAR_YPFD (380 - 780 nm) 313.4
# PAR_YPFD (400 - 700 nm) 311.8
# PAR_YPFD B (400 - 499 nm) 73.67
# PAR_YPFD FR (701 - 780 nm) 1.45
# PAR_YPFD G (500 - 599 nm) 18.17
# PAR_YPFD R (600 - 700 nm) 219.97
# PAR_YPFD UV (380 - 399 nm) 0.15

# %%
x1=df["humidity"]
x2=df["water temp"]
x3=df["ph"]
x4=df["ec"]
x5=df["temp"]
x6=df["PAR_DLI"]
x7=df["PAR_Illuminance"]
x8=df["PAR_PPFD (400 - 700 nm)"]
x9=df["PAR_PPFD B (400 - 499 nm)"]
x10=df["PAR_PPFD FR (701 - 780 nm)"]
x11=df["PAR_PPFD G (500 - 599 nm)"]
x12=df["PAR_PPFD R (600 - 700 nm)"]
x13=df["PAR_PPFD UV (380 - 399 nm)"]
x14=df["PAR_R/B"]
x15=df["PAR_R/FR"]
x16=df["PAR_YPFD (380 - 780 nm)"]
x17=df["PAR_YPFD (400 - 700 nm)"]
x18=df["PAR_YPFD B (400 - 499 nm)"]
x19=df["PAR_YPFD FR (701 - 780 nm)"]
x20=df["PAR_YPFD G (500 - 599 nm)"]
x21=df["PAR_YPFD R (600 - 700 nm)"]
x22=df["PAR_YPFD UV (380 - 399 nm)"]


var=df["Ca"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]
max_x6=x6[max_index]
max_x7=x7[max_index]
max_x8=x8[max_index]
max_x9=x9[max_index]
max_x10=x10[max_index]
max_x11=x11[max_index]
max_x12=x12[max_index]
max_x13=x13[max_index]
max_x14=x14[max_index]
max_x15=x15[max_index]
max_x16=x16[max_index]
max_x17=x17[max_index]
max_x18=x18[max_index]
max_x19=x19[max_index]
max_x20=x20[max_index]
max_x21=x21[max_index]
max_x22=x22[max_index]

print("Calcium")
print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
print("PAR_DLI",max_x6)
print("PAR_Illuminance",max_x7)
print("PAR_PPFD (400 - 700 nm)",max_x8)
print("PAR_PPFD B (400 - 499 nm)",max_x9)
print("PAR_PPFD FR (701 - 780 nm)",max_x10)
print("PAR_PPFD G (500 - 599 nm)",max_x11)
print("PAR_PPFD R (600 - 700 nm)",max_x12)
print("PAR_PPFD UV (380 - 399 nm)",max_x13)
print("PAR_R/B",max_x14)
print("PAR_R/FR",max_x15)
print("PAR_YPFD (380 - 780 nm)",max_x16)
print("PAR_YPFD (400 - 700 nm)",max_x17)
print("PAR_YPFD B (400 - 499 nm)",max_x18)
print("PAR_YPFD FR (701 - 780 nm)",max_x19)
print("PAR_YPFD G (500 - 599 nm)",max_x20)
print("PAR_YPFD R (600 - 700 nm)",max_x21)
print("PAR_YPFD UV (380 - 399 nm)",max_x22)
# Out:
# Calcium
# humidity 61.41
# water temp 24.4
# ph 6.48
# ec 1.92
# temperature 22.48
# PAR_DLI 33.67
# PAR_Illuminance 6931.0
# PAR_PPFD (400 - 700 nm) 389.79
# PAR_PPFD B (400 - 499 nm) 111.5
# PAR_PPFD FR (701 - 780 nm) 6.68
# PAR_PPFD G (500 - 599 nm) 22.55
# PAR_PPFD R (600 - 700 nm) 255.75
# PAR_PPFD UV (380 - 399 nm) 0.26
# PAR_R/B 2.29
# PAR_R/FR 38.27
# PAR_YPFD (380 - 780 nm) 339.68
# PAR_YPFD (400 - 700 nm) 338.04
# PAR_YPFD B (400 - 499 nm) 81.63
# PAR_YPFD FR (701 - 780 nm) 1.48
# PAR_YPFD G (500 - 599 nm) 19.94
# PAR_YPFD R (600 - 700 nm) 236.5
# PAR_YPFD UV (380 - 399 nm) 0.15

# %%
x1=df["humidity"]
x2=df["water temp"]
x3=df["ph"]
x4=df["ec"]
x5=df["temp"]
x6=df["PAR_DLI"]
x7=df["PAR_Illuminance"]
x8=df["PAR_PPFD (400 - 700 nm)"]
x9=df["PAR_PPFD B (400 - 499 nm)"]
x10=df["PAR_PPFD FR (701 - 780 nm)"]
x11=df["PAR_PPFD G (500 - 599 nm)"]
x12=df["PAR_PPFD R (600 - 700 nm)"]
x13=df["PAR_PPFD UV (380 - 399 nm)"]
x14=df["PAR_R/B"]
x15=df["PAR_R/FR"]
x16=df["PAR_YPFD (380 - 780 nm)"]
x17=df["PAR_YPFD (400 - 700 nm)"]
x18=df["PAR_YPFD B (400 - 499 nm)"]
x19=df["PAR_YPFD FR (701 - 780 nm)"]
x20=df["PAR_YPFD G (500 - 599 nm)"]
x21=df["PAR_YPFD R (600 - 700 nm)"]
x22=df["PAR_YPFD UV (380 - 399 nm)"]


var=df["Mg"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]
max_x6=x6[max_index]
max_x7=x7[max_index]
max_x8=x8[max_index]
max_x9=x9[max_index]
max_x10=x10[max_index]
max_x11=x11[max_index]
max_x12=x12[max_index]
max_x13=x13[max_index]
max_x14=x14[max_index]
max_x15=x15[max_index]
max_x16=x16[max_index]
max_x17=x17[max_index]
max_x18=x18[max_index]
max_x19=x19[max_index]
max_x20=x20[max_index]
max_x21=x21[max_index]
max_x22=x22[max_index]

print("Magnesium\n\n")
print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
print("PAR_DLI",max_x6)
print("PAR_Illuminance",max_x7)
print("PAR_PPFD (400 - 700 nm)",max_x8)
print("PAR_PPFD B (400 - 499 nm)",max_x9)
print("PAR_PPFD FR (701 - 780 nm)",max_x10)
print("PAR_PPFD G (500 - 599 nm)",max_x11)
print("PAR_PPFD R (600 - 700 nm)",max_x12)
print("PAR_PPFD UV (380 - 399 nm)",max_x13)
print("PAR_R/B",max_x14)
print("PAR_R/FR",max_x15)
print("PAR_YPFD (380 - 780 nm)",max_x16)
print("PAR_YPFD (400 - 700 nm)",max_x17)
print("PAR_YPFD B (400 - 499 nm)",max_x18)
print("PAR_YPFD FR (701 - 780 nm)",max_x19)
print("PAR_YPFD G (500 - 599 nm)",max_x20)
print("PAR_YPFD R (600 - 700 nm)",max_x21)
print("PAR_YPFD UV (380 - 399 nm)",max_x22)
# Out:
# Magnesium
#
#
# humidity 58.02
# water temp 24.06
# ph 6.27
# ec 2.82
# temperature 22.54
# PAR_DLI 26.89
# PAR_Illuminance 5343.22
# PAR_PPFD (400 - 700 nm) 311.32
# PAR_PPFD B (400 - 499 nm) 85.38
# PAR_PPFD FR (701 - 780 nm) 6.13
# PAR_PPFD G (500 - 599 nm) 17.89
# PAR_PPFD R (600 - 700 nm) 208.05
# PAR_PPFD UV (380 - 399 nm) 0.23
# PAR_R/B 2.43
# PAR_R/FR 33.9
# PAR_YPFD (380 - 780 nm) 271.28
# PAR_YPFD (400 - 700 nm) 269.81
# PAR_YPFD B (400 - 499 nm) 62.48
# PAR_YPFD FR (701 - 780 nm) 1.32
# PAR_YPFD G (500 - 599 nm) 15.8
# PAR_YPFD R (600 - 700 nm) 191.54
# PAR_YPFD UV (380 - 399 nm) 0.13

# %%
x1=df["humidity"]
x2=df["water temp"]
x3=df["ph"]
x4=df["ec"]
x5=df["temp"]
x6=df["PAR_DLI"]
x7=df["PAR_Illuminance"]
x8=df["PAR_PPFD (400 - 700 nm)"]
x9=df["PAR_PPFD B (400 - 499 nm)"]
x10=df["PAR_PPFD FR (701 - 780 nm)"]
x11=df["PAR_PPFD G (500 - 599 nm)"]
x12=df["PAR_PPFD R (600 - 700 nm)"]
x13=df["PAR_PPFD UV (380 - 399 nm)"]
x14=df["PAR_R/B"]
x15=df["PAR_R/FR"]
x16=df["PAR_YPFD (380 - 780 nm)"]
x17=df["PAR_YPFD (400 - 700 nm)"]
x18=df["PAR_YPFD B (400 - 499 nm)"]
x19=df["PAR_YPFD FR (701 - 780 nm)"]
x20=df["PAR_YPFD G (500 - 599 nm)"]
x21=df["PAR_YPFD R (600 - 700 nm)"]
x22=df["PAR_YPFD UV (380 - 399 nm)"]


var=df["S"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]
max_x6=x6[max_index]
max_x7=x7[max_index]
max_x8=x8[max_index]
max_x9=x9[max_index]
max_x10=x10[max_index]
max_x11=x11[max_index]
max_x12=x12[max_index]
max_x13=x13[max_index]
max_x14=x14[max_index]
max_x15=x15[max_index]
max_x16=x16[max_index]
max_x17=x17[max_index]
max_x18=x18[max_index]
max_x19=x19[max_index]
max_x20=x20[max_index]
max_x21=x21[max_index]
max_x22=x22[max_index]

print("Sulphur\n\n")
print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
print("PAR_DLI",max_x6)
print("PAR_Illuminance",max_x7)
print("PAR_PPFD (400 - 700 nm)",max_x8)
print("PAR_PPFD B (400 - 499 nm)",max_x9)
print("PAR_PPFD FR (701 - 780 nm)",max_x10)
print("PAR_PPFD G (500 - 599 nm)",max_x11)
print("PAR_PPFD R (600 - 700 nm)",max_x12)
print("PAR_PPFD UV (380 - 399 nm)",max_x13)
print("PAR_R/B",max_x14)
print("PAR_R/FR",max_x15)
print("PAR_YPFD (380 - 780 nm)",max_x16)
print("PAR_YPFD (400 - 700 nm)",max_x17)
print("PAR_YPFD B (400 - 499 nm)",max_x18)
print("PAR_YPFD FR (701 - 780 nm)",max_x19)
print("PAR_YPFD G (500 - 599 nm)",max_x20)
print("PAR_YPFD R (600 - 700 nm)",max_x21)
print("PAR_YPFD UV (380 - 399 nm)",max_x22)
# Out:
# Sulphur
#
#
# humidity 60.1
# water temp 24.36
# ph 6.2
# ec 2.44
# temperature 22.55
# PAR_DLI 36.51
# PAR_Illuminance 7382.94
# PAR_PPFD (400 - 700 nm) 422.66
# PAR_PPFD B (400 - 499 nm) 119.22
# PAR_PPFD FR (701 - 780 nm) 7.97
# PAR_PPFD G (500 - 599 nm) 24.51
# PAR_PPFD R (600 - 700 nm) 278.93
# PAR_PPFD UV (380 - 399 nm) 0.31
# PAR_R/B 2.36
# PAR_R/FR 35.24
# PAR_YPFD (380 - 780 nm) 367.77
# PAR_YPFD (400 - 700 nm) 365.81
# PAR_YPFD B (400 - 499 nm) 87.25
# PAR_YPFD FR (701 - 780 nm) 1.78
# PAR_YPFD G (500 - 599 nm) 21.66
# PAR_YPFD R (600 - 700 nm) 256.92
# PAR_YPFD UV (380 - 399 nm) 0.18

# %%
x1=df["humidity"]
x2=df["water temp"]
x3=df["ph"]
x4=df["ec"]
x5=df["temp"]
x6=df["PAR_DLI"]
x7=df["PAR_Illuminance"]
x8=df["PAR_PPFD (400 - 700 nm)"]
x9=df["PAR_PPFD B (400 - 499 nm)"]
x10=df["PAR_PPFD FR (701 - 780 nm)"]
x11=df["PAR_PPFD G (500 - 599 nm)"]
x12=df["PAR_PPFD R (600 - 700 nm)"]
x13=df["PAR_PPFD UV (380 - 399 nm)"]
x14=df["PAR_R/B"]
x15=df["PAR_R/FR"]
x16=df["PAR_YPFD (380 - 780 nm)"]
x17=df["PAR_YPFD (400 - 700 nm)"]
x18=df["PAR_YPFD B (400 - 499 nm)"]
x19=df["PAR_YPFD FR (701 - 780 nm)"]
x20=df["PAR_YPFD G (500 - 599 nm)"]
x21=df["PAR_YPFD R (600 - 700 nm)"]
x22=df["PAR_YPFD UV (380 - 399 nm)"]


var=df["Fe"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]
max_x6=x6[max_index]
max_x7=x7[max_index]
max_x8=x8[max_index]
max_x9=x9[max_index]
max_x10=x10[max_index]
max_x11=x11[max_index]
max_x12=x12[max_index]
max_x13=x13[max_index]
max_x14=x14[max_index]
max_x15=x15[max_index]
max_x16=x16[max_index]
max_x17=x17[max_index]
max_x18=x18[max_index]
max_x19=x19[max_index]
max_x20=x20[max_index]
max_x21=x21[max_index]
max_x22=x22[max_index]

print("Iron\n\n")
print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
print("PAR_DLI",max_x6)
print("PAR_Illuminance",max_x7)
print("PAR_PPFD (400 - 700 nm)",max_x8)
print("PAR_PPFD B (400 - 499 nm)",max_x9)
print("PAR_PPFD FR (701 - 780 nm)",max_x10)
print("PAR_PPFD G (500 - 599 nm)",max_x11)
print("PAR_PPFD R (600 - 700 nm)",max_x12)
print("PAR_PPFD UV (380 - 399 nm)",max_x13)
print("PAR_R/B",max_x14)
print("PAR_R/FR",max_x15)
print("PAR_YPFD (380 - 780 nm)",max_x16)
print("PAR_YPFD (400 - 700 nm)",max_x17)
print("PAR_YPFD B (400 - 499 nm)",max_x18)
print("PAR_YPFD FR (701 - 780 nm)",max_x19)
print("PAR_YPFD G (500 - 599 nm)",max_x20)
print("PAR_YPFD R (600 - 700 nm)",max_x21)
print("PAR_YPFD UV (380 - 399 nm)",max_x22)
# Out:
# Iron
#
#
# humidity 55.38
# water temp 24.8
# ph 6.39
# ec 2.65
# temperature 22.5
# PAR_DLI 29.41
# PAR_Illuminance 5860.27
# PAR_PPFD (400 - 700 nm) 340.4
# PAR_PPFD B (400 - 499 nm) 95.16
# PAR_PPFD FR (701 - 780 nm) 6.09
# PAR_PPFD G (500 - 599 nm) 19.12
# PAR_PPFD R (600 - 700 nm) 226.14
# PAR_PPFD UV (380 - 399 nm) 0.24
# PAR_R/B 2.37
# PAR_R/FR 37.12
# PAR_YPFD (380 - 780 nm) 296.66
# PAR_YPFD (400 - 700 nm) 295.16
# PAR_YPFD B (400 - 499 nm) 69.66
# PAR_YPFD FR (701 - 780 nm) 1.35
# PAR_YPFD G (500 - 599 nm) 16.89
# PAR_YPFD R (600 - 700 nm) 208.62
# PAR_YPFD UV (380 - 399 nm) 0.14

# %%
x1=df["humidity"]
x2=df["water temp"]
x3=df["ph"]
x4=df["ec"]
x5=df["temp"]
x6=df["PAR_DLI"]
x7=df["PAR_Illuminance"]
x8=df["PAR_PPFD (400 - 700 nm)"]
x9=df["PAR_PPFD B (400 - 499 nm)"]
x10=df["PAR_PPFD FR (701 - 780 nm)"]
x11=df["PAR_PPFD G (500 - 599 nm)"]
x12=df["PAR_PPFD R (600 - 700 nm)"]
x13=df["PAR_PPFD UV (380 - 399 nm)"]
x14=df["PAR_R/B"]
x15=df["PAR_R/FR"]
x16=df["PAR_YPFD (380 - 780 nm)"]
x17=df["PAR_YPFD (400 - 700 nm)"]
x18=df["PAR_YPFD B (400 - 499 nm)"]
x19=df["PAR_YPFD FR (701 - 780 nm)"]
x20=df["PAR_YPFD G (500 - 599 nm)"]
x21=df["PAR_YPFD R (600 - 700 nm)"]
x22=df["PAR_YPFD UV (380 - 399 nm)"]


var=df["Mn"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]
max_x6=x6[max_index]
max_x7=x7[max_index]
max_x8=x8[max_index]
max_x9=x9[max_index]
max_x10=x10[max_index]
max_x11=x11[max_index]
max_x12=x12[max_index]
max_x13=x13[max_index]
max_x14=x14[max_index]
max_x15=x15[max_index]
max_x16=x16[max_index]
max_x17=x17[max_index]
max_x18=x18[max_index]
max_x19=x19[max_index]
max_x20=x20[max_index]
max_x21=x21[max_index]
max_x22=x22[max_index]

print("Manganese\n\n")
print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
print("PAR_DLI",max_x6)
print("PAR_Illuminance",max_x7)
print("PAR_PPFD (400 - 700 nm)",max_x8)
print("PAR_PPFD B (400 - 499 nm)",max_x9)
print("PAR_PPFD FR (701 - 780 nm)",max_x10)
print("PAR_PPFD G (500 - 599 nm)",max_x11)
print("PAR_PPFD R (600 - 700 nm)",max_x12)
print("PAR_PPFD UV (380 - 399 nm)",max_x13)
print("PAR_R/B",max_x14)
print("PAR_R/FR",max_x15)
print("PAR_YPFD (380 - 780 nm)",max_x16)
print("PAR_YPFD (400 - 700 nm)",max_x17)
print("PAR_YPFD B (400 - 499 nm)",max_x18)
print("PAR_YPFD FR (701 - 780 nm)",max_x19)
print("PAR_YPFD G (500 - 599 nm)",max_x20)
print("PAR_YPFD R (600 - 700 nm)",max_x21)
print("PAR_YPFD UV (380 - 399 nm)",max_x22)
# Out:
# Manganese
#
#
# humidity 61.08
# water temp 24.0
# ph 6.25
# ec 2.65
# temperature 22.41
# PAR_DLI 32.52
# PAR_Illuminance 6488.11
# PAR_PPFD (400 - 700 nm) 376.46
# PAR_PPFD B (400 - 499 nm) 103.36
# PAR_PPFD FR (701 - 780 nm) 7.19
# PAR_PPFD G (500 - 599 nm) 21.38
# PAR_PPFD R (600 - 700 nm) 251.73
# PAR_PPFD UV (380 - 399 nm) 0.28
# PAR_R/B 2.44
# PAR_R/FR 35.22
# PAR_YPFD (380 - 780 nm) 328.14
# PAR_YPFD (400 - 700 nm) 326.38
# PAR_YPFD B (400 - 499 nm) 75.62
# PAR_YPFD FR (701 - 780 nm) 1.58
# PAR_YPFD G (500 - 599 nm) 18.89
# PAR_YPFD R (600 - 700 nm) 231.89
# PAR_YPFD UV (380 - 399 nm) 0.17

# %%
x1=df["humidity"]
x2=df["water temp"]
x3=df["ph"]
x4=df["ec"]
x5=df["temp"]
x6=df["PAR_DLI"]
x7=df["PAR_Illuminance"]
x8=df["PAR_PPFD (400 - 700 nm)"]
x9=df["PAR_PPFD B (400 - 499 nm)"]
x10=df["PAR_PPFD FR (701 - 780 nm)"]
x11=df["PAR_PPFD G (500 - 599 nm)"]
x12=df["PAR_PPFD R (600 - 700 nm)"]
x13=df["PAR_PPFD UV (380 - 399 nm)"]
x14=df["PAR_R/B"]
x15=df["PAR_R/FR"]
x16=df["PAR_YPFD (380 - 780 nm)"]
x17=df["PAR_YPFD (400 - 700 nm)"]
x18=df["PAR_YPFD B (400 - 499 nm)"]
x19=df["PAR_YPFD FR (701 - 780 nm)"]
x20=df["PAR_YPFD G (500 - 599 nm)"]
x21=df["PAR_YPFD R (600 - 700 nm)"]
x22=df["PAR_YPFD UV (380 - 399 nm)"]


var=df["B"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]
max_x6=x6[max_index]
max_x7=x7[max_index]
max_x8=x8[max_index]
max_x9=x9[max_index]
max_x10=x10[max_index]
max_x11=x11[max_index]
max_x12=x12[max_index]
max_x13=x13[max_index]
max_x14=x14[max_index]
max_x15=x15[max_index]
max_x16=x16[max_index]
max_x17=x17[max_index]
max_x18=x18[max_index]
max_x19=x19[max_index]
max_x20=x20[max_index]
max_x21=x21[max_index]
max_x22=x22[max_index]

print("Boron\n\n")
print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
print("PAR_DLI",max_x6)
print("PAR_Illuminance",max_x7)
print("PAR_PPFD (400 - 700 nm)",max_x8)
print("PAR_PPFD B (400 - 499 nm)",max_x9)
print("PAR_PPFD FR (701 - 780 nm)",max_x10)
print("PAR_PPFD G (500 - 599 nm)",max_x11)
print("PAR_PPFD R (600 - 700 nm)",max_x12)
print("PAR_PPFD UV (380 - 399 nm)",max_x13)
print("PAR_R/B",max_x14)
print("PAR_R/FR",max_x15)
print("PAR_YPFD (380 - 780 nm)",max_x16)
print("PAR_YPFD (400 - 700 nm)",max_x17)
print("PAR_YPFD B (400 - 499 nm)",max_x18)
print("PAR_YPFD FR (701 - 780 nm)",max_x19)
print("PAR_YPFD G (500 - 599 nm)",max_x20)
print("PAR_YPFD R (600 - 700 nm)",max_x21)
print("PAR_YPFD UV (380 - 399 nm)",max_x22)
# Out:
# Boron
#
#
# humidity 58.02
# water temp 24.06
# ph 6.27
# ec 2.82
# temperature 22.54
# PAR_DLI 26.89
# PAR_Illuminance 5343.22
# PAR_PPFD (400 - 700 nm) 311.32
# PAR_PPFD B (400 - 499 nm) 85.38
# PAR_PPFD FR (701 - 780 nm) 6.13
# PAR_PPFD G (500 - 599 nm) 17.89
# PAR_PPFD R (600 - 700 nm) 208.05
# PAR_PPFD UV (380 - 399 nm) 0.23
# PAR_R/B 2.43
# PAR_R/FR 33.9
# PAR_YPFD (380 - 780 nm) 271.28
# PAR_YPFD (400 - 700 nm) 269.81
# PAR_YPFD B (400 - 499 nm) 62.48
# PAR_YPFD FR (701 - 780 nm) 1.32
# PAR_YPFD G (500 - 599 nm) 15.8
# PAR_YPFD R (600 - 700 nm) 191.54
# PAR_YPFD UV (380 - 399 nm) 0.13

# %%
x1=df["humidity"]
x2=df["water temp"]
x3=df["ph"]
x4=df["ec"]
x5=df["temp"]
x6=df["PAR_DLI"]
x7=df["PAR_Illuminance"]
x8=df["PAR_PPFD (400 - 700 nm)"]
x9=df["PAR_PPFD B (400 - 499 nm)"]
x10=df["PAR_PPFD FR (701 - 780 nm)"]
x11=df["PAR_PPFD G (500 - 599 nm)"]
x12=df["PAR_PPFD R (600 - 700 nm)"]
x13=df["PAR_PPFD UV (380 - 399 nm)"]
x14=df["PAR_R/B"]
x15=df["PAR_R/FR"]
x16=df["PAR_YPFD (380 - 780 nm)"]
x17=df["PAR_YPFD (400 - 700 nm)"]
x18=df["PAR_YPFD B (400 - 499 nm)"]
x19=df["PAR_YPFD FR (701 - 780 nm)"]
x20=df["PAR_YPFD G (500 - 599 nm)"]
x21=df["PAR_YPFD R (600 - 700 nm)"]
x22=df["PAR_YPFD UV (380 - 399 nm)"]


var=df["Cu"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]
max_x6=x6[max_index]
max_x7=x7[max_index]
max_x8=x8[max_index]
max_x9=x9[max_index]
max_x10=x10[max_index]
max_x11=x11[max_index]
max_x12=x12[max_index]
max_x13=x13[max_index]
max_x14=x14[max_index]
max_x15=x15[max_index]
max_x16=x16[max_index]
max_x17=x17[max_index]
max_x18=x18[max_index]
max_x19=x19[max_index]
max_x20=x20[max_index]
max_x21=x21[max_index]
max_x22=x22[max_index]

print("Copper\n\n")
print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
print("PAR_DLI",max_x6)
print("PAR_Illuminance",max_x7)
print("PAR_PPFD (400 - 700 nm)",max_x8)
print("PAR_PPFD B (400 - 499 nm)",max_x9)
print("PAR_PPFD FR (701 - 780 nm)",max_x10)
print("PAR_PPFD G (500 - 599 nm)",max_x11)
print("PAR_PPFD R (600 - 700 nm)",max_x12)
print("PAR_PPFD UV (380 - 399 nm)",max_x13)
print("PAR_R/B",max_x14)
print("PAR_R/FR",max_x15)
print("PAR_YPFD (380 - 780 nm)",max_x16)
print("PAR_YPFD (400 - 700 nm)",max_x17)
print("PAR_YPFD B (400 - 499 nm)",max_x18)
print("PAR_YPFD FR (701 - 780 nm)",max_x19)
print("PAR_YPFD G (500 - 599 nm)",max_x20)
print("PAR_YPFD R (600 - 700 nm)",max_x21)
print("PAR_YPFD UV (380 - 399 nm)",max_x22)
# Out:
# Copper
#
#
# humidity 61.41
# water temp 24.4
# ph 6.48
# ec 1.92
# temperature 22.48
# PAR_DLI 33.67
# PAR_Illuminance 6931.0
# PAR_PPFD (400 - 700 nm) 389.79
# PAR_PPFD B (400 - 499 nm) 111.5
# PAR_PPFD FR (701 - 780 nm) 6.68
# PAR_PPFD G (500 - 599 nm) 22.55
# PAR_PPFD R (600 - 700 nm) 255.75
# PAR_PPFD UV (380 - 399 nm) 0.26
# PAR_R/B 2.29
# PAR_R/FR 38.27
# PAR_YPFD (380 - 780 nm) 339.68
# PAR_YPFD (400 - 700 nm) 338.04
# PAR_YPFD B (400 - 499 nm) 81.63
# PAR_YPFD FR (701 - 780 nm) 1.48
# PAR_YPFD G (500 - 599 nm) 19.94
# PAR_YPFD R (600 - 700 nm) 236.5
# PAR_YPFD UV (380 - 399 nm) 0.15

# %%
x1=df["humidity"]
x2=df["water temp"]
x3=df["ph"]
x4=df["ec"]
x5=df["temp"]
x6=df["PAR_DLI"]
x7=df["PAR_Illuminance"]
x8=df["PAR_PPFD (400 - 700 nm)"]
x9=df["PAR_PPFD B (400 - 499 nm)"]
x10=df["PAR_PPFD FR (701 - 780 nm)"]
x11=df["PAR_PPFD G (500 - 599 nm)"]
x12=df["PAR_PPFD R (600 - 700 nm)"]
x13=df["PAR_PPFD UV (380 - 399 nm)"]
x14=df["PAR_R/B"]
x15=df["PAR_R/FR"]
x16=df["PAR_YPFD (380 - 780 nm)"]
x17=df["PAR_YPFD (400 - 700 nm)"]
x18=df["PAR_YPFD B (400 - 499 nm)"]
x19=df["PAR_YPFD FR (701 - 780 nm)"]
x20=df["PAR_YPFD G (500 - 599 nm)"]
x21=df["PAR_YPFD R (600 - 700 nm)"]
x22=df["PAR_YPFD UV (380 - 399 nm)"]


var=df["Zn"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]
max_x6=x6[max_index]
max_x7=x7[max_index]
max_x8=x8[max_index]
max_x9=x9[max_index]
max_x10=x10[max_index]
max_x11=x11[max_index]
max_x12=x12[max_index]
max_x13=x13[max_index]
max_x14=x14[max_index]
max_x15=x15[max_index]
max_x16=x16[max_index]
max_x17=x17[max_index]
max_x18=x18[max_index]
max_x19=x19[max_index]
max_x20=x20[max_index]
max_x21=x21[max_index]
max_x22=x22[max_index]

print("Zinc\n\n")
print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
print("PAR_DLI",max_x6)
print("PAR_Illuminance",max_x7)
print("PAR_PPFD (400 - 700 nm)",max_x8)
print("PAR_PPFD B (400 - 499 nm)",max_x9)
print("PAR_PPFD FR (701 - 780 nm)",max_x10)
print("PAR_PPFD G (500 - 599 nm)",max_x11)
print("PAR_PPFD R (600 - 700 nm)",max_x12)
print("PAR_PPFD UV (380 - 399 nm)",max_x13)
print("PAR_R/B",max_x14)
print("PAR_R/FR",max_x15)
print("PAR_YPFD (380 - 780 nm)",max_x16)
print("PAR_YPFD (400 - 700 nm)",max_x17)
print("PAR_YPFD B (400 - 499 nm)",max_x18)
print("PAR_YPFD FR (701 - 780 nm)",max_x19)
print("PAR_YPFD G (500 - 599 nm)",max_x20)
print("PAR_YPFD R (600 - 700 nm)",max_x21)
print("PAR_YPFD UV (380 - 399 nm)",max_x22)
# Out:
# Zinc
#
#
# humidity 61.08
# water temp 24.0
# ph 6.25
# ec 2.65
# temperature 22.41
# PAR_DLI 32.52
# PAR_Illuminance 6488.11
# PAR_PPFD (400 - 700 nm) 376.46
# PAR_PPFD B (400 - 499 nm) 103.36
# PAR_PPFD FR (701 - 780 nm) 7.19
# PAR_PPFD G (500 - 599 nm) 21.38
# PAR_PPFD R (600 - 700 nm) 251.73
# PAR_PPFD UV (380 - 399 nm) 0.28
# PAR_R/B 2.44
# PAR_R/FR 35.22
# PAR_YPFD (380 - 780 nm) 328.14
# PAR_YPFD (400 - 700 nm) 326.38
# PAR_YPFD B (400 - 499 nm) 75.62
# PAR_YPFD FR (701 - 780 nm) 1.58
# PAR_YPFD G (500 - 599 nm) 18.89
# PAR_YPFD R (600 - 700 nm) 231.89
# PAR_YPFD UV (380 - 399 nm) 0.17

# %%
x1=df["humidity"]
x2=df["water temp"]
x3=df["ph"]
x4=df["ec"]
x5=df["temp"]
x6=df["PAR_DLI"]
x7=df["PAR_Illuminance"]
x8=df["PAR_PPFD (400 - 700 nm)"]
x9=df["PAR_PPFD B (400 - 499 nm)"]
x10=df["PAR_PPFD FR (701 - 780 nm)"]
x11=df["PAR_PPFD G (500 - 599 nm)"]
x12=df["PAR_PPFD R (600 - 700 nm)"]
x13=df["PAR_PPFD UV (380 - 399 nm)"]
x14=df["PAR_R/B"]
x15=df["PAR_R/FR"]
x16=df["PAR_YPFD (380 - 780 nm)"]
x17=df["PAR_YPFD (400 - 700 nm)"]
x18=df["PAR_YPFD B (400 - 499 nm)"]
x19=df["PAR_YPFD FR (701 - 780 nm)"]
x20=df["PAR_YPFD G (500 - 599 nm)"]
x21=df["PAR_YPFD R (600 - 700 nm)"]
x22=df["PAR_YPFD UV (380 - 399 nm)"]


var=df["Mo"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]
max_x6=x6[max_index]
max_x7=x7[max_index]
max_x8=x8[max_index]
max_x9=x9[max_index]
max_x10=x10[max_index]
max_x11=x11[max_index]
max_x12=x12[max_index]
max_x13=x13[max_index]
max_x14=x14[max_index]
max_x15=x15[max_index]
max_x16=x16[max_index]
max_x17=x17[max_index]
max_x18=x18[max_index]
max_x19=x19[max_index]
max_x20=x20[max_index]
max_x21=x21[max_index]
max_x22=x22[max_index]

print("Molybednum\n\n")
print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
print("PAR_DLI",max_x6)
print("PAR_Illuminance",max_x7)
print("PAR_PPFD (400 - 700 nm)",max_x8)
print("PAR_PPFD B (400 - 499 nm)",max_x9)
print("PAR_PPFD FR (701 - 780 nm)",max_x10)
print("PAR_PPFD G (500 - 599 nm)",max_x11)
print("PAR_PPFD R (600 - 700 nm)",max_x12)
print("PAR_PPFD UV (380 - 399 nm)",max_x13)
print("PAR_R/B",max_x14)
print("PAR_R/FR",max_x15)
print("PAR_YPFD (380 - 780 nm)",max_x16)
print("PAR_YPFD (400 - 700 nm)",max_x17)
print("PAR_YPFD B (400 - 499 nm)",max_x18)
print("PAR_YPFD FR (701 - 780 nm)",max_x19)
print("PAR_YPFD G (500 - 599 nm)",max_x20)
print("PAR_YPFD R (600 - 700 nm)",max_x21)
print("PAR_YPFD UV (380 - 399 nm)",max_x22)
# Out:
# Molybednum
#
#
# humidity 61.41
# water temp 24.4
# ph 6.48
# ec 1.92
# temperature 22.48
# PAR_DLI 33.67
# PAR_Illuminance 6931.0
# PAR_PPFD (400 - 700 nm) 389.79
# PAR_PPFD B (400 - 499 nm) 111.5
# PAR_PPFD FR (701 - 780 nm) 6.68
# PAR_PPFD G (500 - 599 nm) 22.55
# PAR_PPFD R (600 - 700 nm) 255.75
# PAR_PPFD UV (380 - 399 nm) 0.26
# PAR_R/B 2.29
# PAR_R/FR 38.27
# PAR_YPFD (380 - 780 nm) 339.68
# PAR_YPFD (400 - 700 nm) 338.04
# PAR_YPFD B (400 - 499 nm) 81.63
# PAR_YPFD FR (701 - 780 nm) 1.48
# PAR_YPFD G (500 - 599 nm) 19.94
# PAR_YPFD R (600 - 700 nm) 236.5
# PAR_YPFD UV (380 - 399 nm) 0.15

# %%
x1=df["humidity"]
x2=df["water temp"]
x3=df["ph"]
x4=df["ec"]
x5=df["temp"]
x6=df["PAR_DLI"]
x7=df["PAR_Illuminance"]
x8=df["PAR_PPFD (400 - 700 nm)"]
x9=df["PAR_PPFD B (400 - 499 nm)"]
x10=df["PAR_PPFD FR (701 - 780 nm)"]
x11=df["PAR_PPFD G (500 - 599 nm)"]
x12=df["PAR_PPFD R (600 - 700 nm)"]
x13=df["PAR_PPFD UV (380 - 399 nm)"]
x14=df["PAR_R/B"]
x15=df["PAR_R/FR"]
x16=df["PAR_YPFD (380 - 780 nm)"]
x17=df["PAR_YPFD (400 - 700 nm)"]
x18=df["PAR_YPFD B (400 - 499 nm)"]
x19=df["PAR_YPFD FR (701 - 780 nm)"]
x20=df["PAR_YPFD G (500 - 599 nm)"]
x21=df["PAR_YPFD R (600 - 700 nm)"]
x22=df["PAR_YPFD UV (380 - 399 nm)"]


var=df["Na"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]
max_x6=x6[max_index]
max_x7=x7[max_index]
max_x8=x8[max_index]
max_x9=x9[max_index]
max_x10=x10[max_index]
max_x11=x11[max_index]
max_x12=x12[max_index]
max_x13=x13[max_index]
max_x14=x14[max_index]
max_x15=x15[max_index]
max_x16=x16[max_index]
max_x17=x17[max_index]
max_x18=x18[max_index]
max_x19=x19[max_index]
max_x20=x20[max_index]
max_x21=x21[max_index]
max_x22=x22[max_index]

print("Sodium\n\n")
print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
print("PAR_DLI",max_x6)
print("PAR_Illuminance",max_x7)
print("PAR_PPFD (400 - 700 nm)",max_x8)
print("PAR_PPFD B (400 - 499 nm)",max_x9)
print("PAR_PPFD FR (701 - 780 nm)",max_x10)
print("PAR_PPFD G (500 - 599 nm)",max_x11)
print("PAR_PPFD R (600 - 700 nm)",max_x12)
print("PAR_PPFD UV (380 - 399 nm)",max_x13)
print("PAR_R/B",max_x14)
print("PAR_R/FR",max_x15)
print("PAR_YPFD (380 - 780 nm)",max_x16)
print("PAR_YPFD (400 - 700 nm)",max_x17)
print("PAR_YPFD B (400 - 499 nm)",max_x18)
print("PAR_YPFD FR (701 - 780 nm)",max_x19)
print("PAR_YPFD G (500 - 599 nm)",max_x20)
print("PAR_YPFD R (600 - 700 nm)",max_x21)
print("PAR_YPFD UV (380 - 399 nm)",max_x22)
# Out:
# Sodium
#
#
# humidity 61.41
# water temp 24.4
# ph 6.48
# ec 1.92
# temperature 22.48
# PAR_DLI 33.67
# PAR_Illuminance 6931.0
# PAR_PPFD (400 - 700 nm) 389.79
# PAR_PPFD B (400 - 499 nm) 111.5
# PAR_PPFD FR (701 - 780 nm) 6.68
# PAR_PPFD G (500 - 599 nm) 22.55
# PAR_PPFD R (600 - 700 nm) 255.75
# PAR_PPFD UV (380 - 399 nm) 0.26
# PAR_R/B 2.29
# PAR_R/FR 38.27
# PAR_YPFD (380 - 780 nm) 339.68
# PAR_YPFD (400 - 700 nm) 338.04
# PAR_YPFD B (400 - 499 nm) 81.63
# PAR_YPFD FR (701 - 780 nm) 1.48
# PAR_YPFD G (500 - 599 nm) 19.94
# PAR_YPFD R (600 - 700 nm) 236.5
# PAR_YPFD UV (380 - 399 nm) 0.15

# %%
x1=df["humidity"]
x2=df["water temp"]
x3=df["ph"]
x4=df["ec"]
x5=df["temp"]
x6=df["PAR_DLI"]
x7=df["PAR_Illuminance"]
x8=df["PAR_PPFD (400 - 700 nm)"]
x9=df["PAR_PPFD B (400 - 499 nm)"]
x10=df["PAR_PPFD FR (701 - 780 nm)"]
x11=df["PAR_PPFD G (500 - 599 nm)"]
x12=df["PAR_PPFD R (600 - 700 nm)"]
x13=df["PAR_PPFD UV (380 - 399 nm)"]
x14=df["PAR_R/B"]
x15=df["PAR_R/FR"]
x16=df["PAR_YPFD (380 - 780 nm)"]
x17=df["PAR_YPFD (400 - 700 nm)"]
x18=df["PAR_YPFD B (400 - 499 nm)"]
x19=df["PAR_YPFD FR (701 - 780 nm)"]
x20=df["PAR_YPFD G (500 - 599 nm)"]
x21=df["PAR_YPFD R (600 - 700 nm)"]
x22=df["PAR_YPFD UV (380 - 399 nm)"]


var=df["Al"]
max_index=np.argmax(var)

max_x1=x1[max_index]
max_x2=x2[max_index]
max_x3=x3[max_index]
max_x4=x4[max_index]
max_x5=x5[max_index]
max_x6=x6[max_index]
max_x7=x7[max_index]
max_x8=x8[max_index]
max_x9=x9[max_index]
max_x10=x10[max_index]
max_x11=x11[max_index]
max_x12=x12[max_index]
max_x13=x13[max_index]
max_x14=x14[max_index]
max_x15=x15[max_index]
max_x16=x16[max_index]
max_x17=x17[max_index]
max_x18=x18[max_index]
max_x19=x19[max_index]
max_x20=x20[max_index]
max_x21=x21[max_index]
max_x22=x22[max_index]

print("Aluminium\n\n")
print("humidity",max_x1)
print("water temp",max_x2)
print("ph",max_x3)
print("ec",max_x4)
print("temperature",max_x5)
print("PAR_DLI",max_x6)
print("PAR_Illuminance",max_x7)
print("PAR_PPFD (400 - 700 nm)",max_x8)
print("PAR_PPFD B (400 - 499 nm)",max_x9)
print("PAR_PPFD FR (701 - 780 nm)",max_x10)
print("PAR_PPFD G (500 - 599 nm)",max_x11)
print("PAR_PPFD R (600 - 700 nm)",max_x12)
print("PAR_PPFD UV (380 - 399 nm)",max_x13)
print("PAR_R/B",max_x14)
print("PAR_R/FR",max_x15)
print("PAR_YPFD (380 - 780 nm)",max_x16)
print("PAR_YPFD (400 - 700 nm)",max_x17)
print("PAR_YPFD B (400 - 499 nm)",max_x18)
print("PAR_YPFD FR (701 - 780 nm)",max_x19)
print("PAR_YPFD G (500 - 599 nm)",max_x20)
print("PAR_YPFD R (600 - 700 nm)",max_x21)
print("PAR_YPFD UV (380 - 399 nm)",max_x22)
# Out:
# Aluminium
#
#
# humidity 58.94
# water temp 24.89
# ph 6.46
# ec 2.56
# temperature 22.93
# PAR_DLI 31.43
# PAR_Illuminance 6424.83
# PAR_PPFD (400 - 700 nm) 363.85
# PAR_PPFD B (400 - 499 nm) 102.34
# PAR_PPFD FR (701 - 780 nm) 6.69
# PAR_PPFD G (500 - 599 nm) 21.13
# PAR_PPFD R (600 - 700 nm) 240.4
# PAR_PPFD UV (380 - 399 nm) 0.27
# PAR_R/B 2.35
# PAR_R/FR 35.85
# PAR_YPFD (380 - 780 nm) 317.15
# PAR_YPFD (400 - 700 nm) 315.53
# PAR_YPFD B (400 - 499 nm) 74.87
# PAR_YPFD FR (701 - 780 nm) 1.44
# PAR_YPFD G (500 - 599 nm) 18.67
# PAR_YPFD R (600 - 700 nm) 222.02
# PAR_YPFD UV (380 - 399 nm) 0.16
